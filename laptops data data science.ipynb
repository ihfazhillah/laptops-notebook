# %%
import pandas

# %%
dataframe = pandas.read_csv('laptops.csv')

# %%
dataframe
# Out:
#      Company                                    Product            TypeName  \
# 1      Apple                                MacBook Pro           Ultrabook
# 2      Apple                                Macbook Air           Ultrabook
# 3         HP                                     250 G6            Notebook
# 4      Apple                                MacBook Pro           Ultrabook
# 5      Apple                                MacBook Pro           Ultrabook
# 6       Acer                                   Aspire 3            Notebook
# 7      Apple                                MacBook Pro           Ultrabook
# 8      Apple                                Macbook Air           Ultrabook
# 9       Asus                            ZenBook UX430UN           Ultrabook
# 10      Acer                                    Swift 3           Ultrabook
# 11        HP                                     250 G6            Notebook
# ...

# %%
dataframe.dtypes
# Out:
# Company              object
# Product              object
# TypeName             object
# Inches              float64
# ScreenResolution     object
# Cpu                  object
# Ram                  object
# Memory               object
# Gpu                  object
# OpSys                object
# Weight               object
# Price_euros         float64
# dtype: object

# %%
dataframe['price_idr'] = dataframe['Price_euros'] * 15823.7

dataframe.to_csv("laptops_with_idr.csv")
